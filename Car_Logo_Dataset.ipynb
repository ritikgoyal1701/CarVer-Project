# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikgoyal1701/CarVer-Project/blob/master/Car_Logo_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **In this notebook we are going to download a dataset from kaggle and uploading it to our kaggle ID**

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai.vision import *
from fastai.metrics import error_rate
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Firstly we upload our kaggle API and then importing libraries.**

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-f5951b39-3816-41bf-940b-ec9c011c611d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5951b39-3816-41bf-940b-ec9c011c611d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
import os
import pandas as pd
cred = pd.read_json("kaggle.json",lines=True)
os.environ['KAGGLE_USERNAME'] = cred.iloc[0][0]
os.environ['KAGGLE_KEY'] = cred.iloc[0][1]

# %% [markdown]
# **Now downloading the dataset from kaggle**
#
# Here we use **!** , because it is a terminal command.

# %%
# !kaggle datasets download -d binhminhs10/10-class-for-car-logo
# Out:
# ...
#  24% 9.00M/37.1M [00:00<00:02, 12.0MB/s]
# 100% 37.1M/37.1M [00:01<00:00, 38.3MB/s]

# %% [markdown]
# **Now, unzipping the dataset we have downloaded from kaggle**

# %%
# !unzip "*.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: trainingdata/TrainingData/Lexus/0002.jpg
#   inflating: trainingdata/TrainingData/Lexus/0003.jpg
#   inflating: trainingdata/TrainingData/Lexus/0004.jpg
#   inflating: trainingdata/TrainingData/Lexus/0005.jpg
#   inflating: trainingdata/TrainingData/Lexus/0006.jpg
#   inflating: trainingdata/TrainingData/Lexus/0007.jpg
#   inflating: trainingdata/TrainingData/Lexus/0008.jpg
#   inflating: trainingdata/TrainingData/Lexus/0009.jpg
#   inflating: trainingdata/TrainingData/Lexus/0010.jpg
#   inflating: trainingdata/TrainingData/Lexus/0011.jpg
#   inflating: trainingdata/TrainingData/Lexus/0012.jpg
#   inflating: trainingdata/TrainingData/Lexus/0013.jpg
#   inflating: trainingdata/TrainingData/Lexus/0014.jpg
#   inflating: trainingdata/TrainingData/Lexus/0015.jpg
#   inflating: trainingdata/TrainingData/Lexus/0016.jpg
#   inflating: trainingdata/TrainingData/Lexus/0017.jpg
# ...

# %% [markdown]
# **Now, we make a new directory to store our dataset and metadata file in a same parent directory.**

# %%
os.makedirs("/content/Car Logo",exist_ok=True)

# %%
# !mv "/content/TrainingData/" "/content/Car Logo/"

# %%
# !mv "/content/TestingData/" "/content/Car Logo/"

# %% [markdown]
# **Metadata.json** file is created here, it stores the information about the dataset.
#
# Here, default metadata file is created.

# %%
# !kaggle datasets init -p "/content/Car Logo/"
# Out:
# Data package template written to: /content/Car Logo/dataset-metadata.json

# %% [markdown]
# Here, we are providing the details about our dataset and then making changes in the **dataset-metadata.json** file.

# %%
var={
    "licenses":[{
         "name":"CC0-1.0"
     }],
     "id":'ritikgoyal1710/Car-Logo-2',
     "title" : "Car Logo 2"
}
with open("/content/Car Logo/dataset-metadata.json", "w") as read_it: 
	json.dump(var, read_it)

# %% [markdown]
# **Now, we will upload it to

# %%
# !kaggle datasets create --dir-mode tar -p "/content/Car Logo/"
# Out:
# Starting upload for file TrainingData.tar
# ...
# 100% 21.8M/21.8M [00:03<00:00, 7.44MB/s]
# Upload successful: TrainingData.tar (22MB)
# Starting upload for file TestingData.tar
# 100% 3.50M/3.50M [00:02<00:00, 1.43MB/s]
# Upload successful: TestingData.tar (3MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/ritikgoyal1710/Car-Logo-2
